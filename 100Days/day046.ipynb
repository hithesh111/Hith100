# %% [markdown]
# <div dir="ltr" style="text-align: left;" trbidi="on">
# <h2 style="text-align: left;">
# <span style="font-size: x-large;">100 Days of ML Day 46</span></h2>
# <h3 style="text-align: left;">
# <span style="font-size: large;">Seaborn: pairplot</span></h3>
# <div style="text-align: left;">
# <span style="font-size: large;"><span style="font-size: small;">Watched a video about pairplots on Seaborn from Data Talks Youtube Channel and played around with important parameters.</span></span></div>
# <div style="text-align: left;">
# <span style="font-size: large;"><span style="font-size: small;">&nbsp;</span> </span></div>
# <b>Topics Covered:</b><br />
# <ul style="text-align: left;">
# <li>pairplots and Parameters</li>
# &nbsp;</ul>
# Code: <a href="https://github.com/hithesh111/Hith100/blob/master/100Days/day046.ipynb">https://github.com/hithesh111/Hith100/blob/master/100Days/day046.ipynb</a><br />
# <br />
# Videos: <br />
# <a href="https://www.youtube.com/watch?v=cpZExlOKFH4">Seaborn Understanding the Weird Parts: pairplot</a></div>

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris,hue='species')

# %%
sns.pairplot(iris,hue='species',markers=['o','s','d'])

# %%
sns.pairplot(iris,vars=['petal_length','petal_width'])

# %%
sns.pairplot(iris,x_vars=['petal_length','petal_width'],y_vars=['sepal_length','sepal_width'])

# %%
sns.pairplot(iris,diag_kind='kde')

# %%
sns.pairplot(iris,diag_kind='hist')

# %%
sns.pairplot(iris,kind='reg')

# %%
sns.pairplot(iris,hue = 'species',kind='reg')
