# %% [markdown]
# <div dir="ltr" style="text-align: left;" trbidi="on">
# <br />
# <h2 style="text-align: left;">
# 100 Days of ML Day 100</h2>
# <h2 style="text-align: left;">
# <b>Saving Models, Scikit-Learn Incorporation</b></h2>
# Watched lectures from sentdex's NLP with Python and NLTK course on Youtube.<br />
# <br />
# Videos:<br />
# <a href="https://www.youtube.com/watch?v=ReakZVh2Xwk&amp;list=PLQVvvaa0QuDf2JswnfiGkliBInZnIC4HL&amp;index=15&amp;t=0s">Save Classifier with Pickle - Natural Language Processing With Python and NLTK p.14</a><br />
# <a href="https://www.youtube.com/watch?v=nla4C-VYNEU&amp;list=PLQVvvaa0QuDf2JswnfiGkliBInZnIC4HL&amp;index=15">Scikit-Learn incorporation - Natural Language Processing With Python and NLTK p.15</a></div>
