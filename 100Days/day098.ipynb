# %% [markdown]
# <div dir="ltr" style="text-align: left;" trbidi="on">
# <h2 style="text-align: left;">
# 100 Days of ML Day 98</h2>
# <h2 style="text-align: left;">
# <b>Wordnet</b></h2>
# Watched lectures from sentdex's NLP with Python and NLTK course on Youtube.<br />
# <br />
# Videos:<br />
# <a href="https://www.youtube.com/watch?v=T68P5-8tM-Y&amp;list=PLQVvvaa0QuDf2JswnfiGkliBInZnIC4HL&amp;index=10">WordNet - Natural Language Processing With Python and NLTK p.10</a></div>
